# %% [markdown]
# <a href="https://colab.research.google.com/github/reneebrecht/human-protein-atlas-image-classification/blob/f1_score/f1_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Get the best model

# %%
# !pip install fsspec # this is needed for pandas
# !pip install gcsfs # this is needed for access the cloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fsspec
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 5.1 MB/s
# Installing collected packages: fsspec
# Successfully installed fsspec-2022.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gcsfs
#   Downloading gcsfs-2022.5.0-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from gcsfs) (1.18.1)
# Requirement already satisfied: fsspec==2022.5.0 in /usr/local/lib/python3.7/dist-packages (from gcsfs) (2022.5.0)
# Collecting aiohttp<4
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.3 MB/s
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.7/dist-packages (from gcsfs) (4.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gcsfs) (2.23.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.7/dist-packages (from gcsfs) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.7/dist-packages (from gcsfs) (0.4.6)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4->gcsfs) (2.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.3 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 53.0 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 57.2 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4->gcsfs) (4.1.1)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4->gcsfs) (21.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (4.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.4.8)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp<4->gcsfs) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib->gcsfs) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs) (2022.6.15)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->gcsfs) (1.0.3)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->gcsfs) (0.4.1)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (1.31.6)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (21.3)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (3.17.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (1.56.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (2022.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (3.0.9)
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, aiohttp, gcsfs
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 gcsfs-2022.5.0 multidict-6.0.2 yarl-1.7.2

# %%
from sklearn.metrics import f1_score
from google.colab import auth
import joblib
import os
import pandas as pd
import numpy as np

# %%
auth.authenticate_user()

# https://cloud.google.com/resource-manager/docs/creating-managing-projects
project_id = ' imposing-league-354107'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# !mkdir -p /tmp/saved_model
# !gsutil cp -r 'gs://human_proteins/saved_model' /tmp/saved_model
# Out:
# Copying gs://human_proteins/saved_model/Ada_Bea_0...
# Copying gs://human_proteins/saved_model/Ada_Bea_1...
# Copying gs://human_proteins/saved_model/Ada_Bea_10...
# Copying gs://human_proteins/saved_model/Ada_Bea_11...
# | [4 files][ 30.4 MiB/ 30.4 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://human_proteins/saved_model/Ada_Bea_12...
# Copying gs://human_proteins/saved_model/Ada_Bea_13...
# Copying gs://human_proteins/saved_model/Ada_Bea_14...
# Copying gs://human_proteins/saved_model/Ada_Bea_15...
# Copying gs://human_proteins/saved_model/Ada_Bea_16...
# Copying gs://human_proteins/saved_model/Ada_Bea_17...
# Copying gs://human_proteins/saved_model/Ada_Bea_18...
# Copying gs://human_proteins/saved_model/Ada_Bea_19...
# Copying gs://human_proteins/saved_model/Ada_Bea_2...
# Copying gs://human_proteins/saved_model/Ada_Bea_20...
# Copying gs://human_proteins/saved_model/Ada_Bea_21...
# Copying gs://human_proteins/saved_model/Ada_Bea_22...
# Copying gs://human_proteins/saved_model/Ada_Bea_23...
# Copying gs://human_proteins/saved_model/Ada_Bea_24...
# Copying gs://human_proteins/saved_model/Ada_Bea_25...
# Copying gs://human_proteins/saved_model/Ada_Bea_26...
# Copying gs://human_proteins/saved_model/Ada_Bea_27...
# Copying gs://human_proteins/saved_model/Ada_Bea_3...
# Copying gs://human_proteins/saved_model/Ada_Bea_4...
# Copying gs://human_proteins/saved_model/Ada_Bea_5...
# Copying gs://human_proteins/saved_model/Ada_Bea_6...
# Copying gs://human_proteins/saved_model/Ada_Bea_7...
# Copying gs://human_proteins/saved_model/Ada_Bea_8...
# Copying gs://human_proteins/saved_model/Ada_Bea_9...
# Copying gs://human_proteins/saved_model/BerNB_Bea_0...
# Copying gs://human_proteins/saved_model/BerNB_Bea_1...
# Copying gs://human_proteins/saved_model/BerNB_Bea_10...
# Copying gs://human_proteins/saved_model/BerNB_Bea_11...
# Copying gs://human_proteins/saved_model/BerNB_Bea_12...
# Copying gs://human_proteins/saved_model/BerNB_Bea_13...
# Copying gs://human_proteins/saved_model/BerNB_Bea_14...
# Copying gs://human_proteins/saved_model/BerNB_Bea_15...
# Copying gs://human_proteins/saved_model/BerNB_Bea_16...
# Copying gs://human_proteins/saved_model/BerNB_Bea_17...
# Copying gs://human_proteins/saved_model/BerNB_Bea_18...
# Copying gs://human_proteins/saved_model/BerNB_Bea_19...
# Copying gs://human_proteins/saved_model/BerNB_Bea_2...
# Copying gs://human_proteins/saved_model/BerNB_Bea_20...
# Copying gs://human_proteins/saved_model/BerNB_Bea_21...
# Copying gs://human_proteins/saved_model/BerNB_Bea_22...
# Copying gs://human_proteins/saved_model/BerNB_Bea_23...
# Copying gs://human_proteins/saved_model/BerNB_Bea_24...
# Copying gs://human_proteins/saved_model/BerNB_Bea_25...
# Copying gs://human_proteins/saved_model/BerNB_Bea_26...
# Copying gs://human_proteins/saved_model/BerNB_Bea_27...
# Copying gs://human_proteins/saved_model/BerNB_Bea_3...
# Copying gs://human_proteins/saved_model/BerNB_Bea_4...
# Copying gs://human_proteins/saved_model/BerNB_Bea_5...
# Copying gs://human_proteins/saved_model/BerNB_Bea_6...
# Copying gs://human_proteins/saved_model/BerNB_Bea_7...
# Copying gs://human_proteins/saved_model/BerNB_Bea_8...
# Copying gs://human_proteins/saved_model/BerNB_Bea_9...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_0...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_1...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_10...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_11...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_12...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_13...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_14...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_15...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_16...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_17...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_18...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_19...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_2...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_20...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_21...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_22...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_23...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_24...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_25...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_26...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_27...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_3...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_4...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_5...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_6...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_7...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_8...
# Copying gs://human_proteins/saved_model/ExtraT_Bea_9...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_0...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_1...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_10...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_11...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_12...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_13...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_14...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_15...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_16...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_17...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_18...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_19...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_2...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_20...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_21...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_22...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_23...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_24...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_25...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_26...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_27...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_3...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_4...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_5...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_6...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_7...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_8...
# Copying gs://human_proteins/saved_model/GradientBoostingClassifier_9...
# Copying gs://human_proteins/saved_model/KNN_0...
# Copying gs://human_proteins/saved_model/KNN_1...
# Copying gs://human_proteins/saved_model/KNN_10...
# Copying gs://human_proteins/saved_model/KNN_11...
# Copying gs://human_proteins/saved_model/KNN_12...
# Copying gs://human_proteins/saved_model/KNN_13...
# Copying gs://human_proteins/saved_model/KNN_14...
# Copying gs://human_proteins/saved_model/KNN_15...
# Copying gs://human_proteins/saved_model/KNN_16...
# Copying gs://human_proteins/saved_model/KNN_17...
# Copying gs://human_proteins/saved_model/KNN_18...
# Copying gs://human_proteins/saved_model/KNN_19...
# Copying gs://human_proteins/saved_model/KNN_2...
# Copying gs://human_proteins/saved_model/KNN_20...
# Copying gs://human_proteins/saved_model/KNN_21...
# Copying gs://human_proteins/saved_model/KNN_22...
# Copying gs://human_proteins/saved_model/KNN_23...
# Copying gs://human_proteins/saved_model/KNN_24...
# Copying gs://human_proteins/saved_model/KNN_25...
# Copying gs://human_proteins/saved_model/KNN_26...
# Copying gs://human_proteins/saved_model/KNN_27...
# Copying gs://human_proteins/saved_model/KNN_3...
# Copying gs://human_proteins/saved_model/KNN_4...
# Copying gs://human_proteins/saved_model/KNN_5...
# Copying gs://human_proteins/saved_model/KNN_6...
# Copying gs://human_proteins/saved_model/KNN_7...
# Copying gs://human_proteins/saved_model/KNN_8...
# Copying gs://human_proteins/saved_model/KNN_9...
# Copying gs://human_proteins/saved_model/PAC_Bea_0...
# Copying gs://human_proteins/saved_model/PAC_Bea_1...
# Copying gs://human_proteins/saved_model/PAC_Bea_10...
# Copying gs://human_proteins/saved_model/PAC_Bea_11...
# Copying gs://human_proteins/saved_model/PAC_Bea_12...
# Copying gs://human_proteins/saved_model/PAC_Bea_13...
# Copying gs://human_proteins/saved_model/PAC_Bea_14...
# Copying gs://human_proteins/saved_model/PAC_Bea_15...
# Copying gs://human_proteins/saved_model/PAC_Bea_16...
# Copying gs://human_proteins/saved_model/PAC_Bea_17...
# Copying gs://human_proteins/saved_model/PAC_Bea_18...
# Copying gs://human_proteins/saved_model/PAC_Bea_19...
# Copying gs://human_proteins/saved_model/PAC_Bea_2...
# Copying gs://human_proteins/saved_model/PAC_Bea_20...
# Copying gs://human_proteins/saved_model/PAC_Bea_21...
# Copying gs://human_proteins/saved_model/PAC_Bea_22...
# Copying gs://human_proteins/saved_model/PAC_Bea_23...
# Copying gs://human_proteins/saved_model/PAC_Bea_24...
# Copying gs://human_proteins/saved_model/PAC_Bea_25...
# Copying gs://human_proteins/saved_model/PAC_Bea_26...
# Copying gs://human_proteins/saved_model/PAC_Bea_27...
# Copying gs://human_proteins/saved_model/PAC_Bea_3...
# Copying gs://human_proteins/saved_model/PAC_Bea_4...
# Copying gs://human_proteins/saved_model/PAC_Bea_5...
# Copying gs://human_proteins/saved_model/PAC_Bea_6...
# Copying gs://human_proteins/saved_model/PAC_Bea_7...
# Copying gs://human_proteins/saved_model/PAC_Bea_8...
# Copying gs://human_proteins/saved_model/PAC_Bea_9...
# Copying gs://human_proteins/saved_model/RF_Bea_0...
# Copying gs://human_proteins/saved_model/RF_Bea_1...
# Copying gs://human_proteins/saved_model/RF_Bea_10...
# Copying gs://human_proteins/saved_model/RF_Bea_11...
# Copying gs://human_proteins/saved_model/RF_Bea_12...
# Copying gs://human_proteins/saved_model/RF_Bea_13...
# Copying gs://human_proteins/saved_model/RF_Bea_14...
# Copying gs://human_proteins/saved_model/RF_Bea_15...
# Copying gs://human_proteins/saved_model/RF_Bea_16...
# Copying gs://human_proteins/saved_model/RF_Bea_17...
# Copying gs://human_proteins/saved_model/RF_Bea_18...
# Copying gs://human_proteins/saved_model/RF_Bea_19...
# Copying gs://human_proteins/saved_model/RF_Bea_2...
# Copying gs://human_proteins/saved_model/RF_Bea_20...
# Copying gs://human_proteins/saved_model/RF_Bea_21...
# Copying gs://human_proteins/saved_model/RF_Bea_22...
# Copying gs://human_proteins/saved_model/RF_Bea_23...
# Copying gs://human_proteins/saved_model/RF_Bea_24...
# Copying gs://human_proteins/saved_model/RF_Bea_25...
# Copying gs://human_proteins/saved_model/RF_Bea_26...
# Copying gs://human_proteins/saved_model/RF_Bea_27...
# Copying gs://human_proteins/saved_model/RF_Bea_3...
# Copying gs://human_proteins/saved_model/RF_Bea_4...
# Copying gs://human_proteins/saved_model/RF_Bea_5...
# Copying gs://human_proteins/saved_model/RF_Bea_6...
# Copying gs://human_proteins/saved_model/RF_Bea_7...
# Copying gs://human_proteins/saved_model/RF_Bea_8...
# Copying gs://human_proteins/saved_model/RF_Bea_9...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_0...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_1...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_10...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_11...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_12...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_13...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_14...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_15...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_16...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_17...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_18...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_19...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_2...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_20...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_21...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_22...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_23...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_24...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_25...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_26...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_27...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_3...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_4...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_5...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_6...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_7...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_8...
# Copying gs://human_proteins/saved_model/RiCcv_Bea_9...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_0...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_1...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_10...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_11...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_12...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_13...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_14...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_15...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_16...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_17...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_18...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_19...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_2...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_20...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_21...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_22...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_23...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_24...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_25...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_26...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_27...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_3...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_4...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_5...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_6...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_7...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_8...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_9...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_0/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_0/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_0/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_0/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_1/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_1/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_1/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_1/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_10/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_10/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_10/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_10/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_11/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_11/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_11/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_11/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_12/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_12/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_12/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_12/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_13/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_13/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_13/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_13/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_14/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_14/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_14/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_14/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_15/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_15/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_15/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_15/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_16/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_16/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_16/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_16/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_17/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_17/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_17/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_17/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_18/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_18/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_18/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_18/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_19/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_19/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_19/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_19/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_2/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_2/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_2/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_2/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_20/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_20/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_20/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_20/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_21/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_21/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_21/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_21/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_22/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_22/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_22/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_22/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_23/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_23/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_23/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_23/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_24/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_24/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_24/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_24/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_25/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_25/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_25/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_25/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_26/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_26/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_26/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_26/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_27/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_27/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_27/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_27/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_3/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_3/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_3/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_3/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_4/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_4/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_4/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_4/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_5/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_5/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_5/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_5/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_6/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_6/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_6/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_6/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_7/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_7/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_7/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_7/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_8/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_8/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_8/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_8/variables/variables.index...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_9/keras_metadata.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_9/saved_model.pb...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_9/variables/variables.data-00000-of-00001...
# Copying gs://human_proteins/saved_model/nn_5_layers_dropout_model_9/variables/variables.index...
# Copying gs://human_proteins/saved_model/svc_rbf_0...
# Copying gs://human_proteins/saved_model/svc_rbf_1...
# Copying gs://human_proteins/saved_model/svc_rbf_10...
# Copying gs://human_proteins/saved_model/svc_rbf_11...
# Copying gs://human_proteins/saved_model/svc_rbf_12...
# Copying gs://human_proteins/saved_model/svc_rbf_13...
# Copying gs://human_proteins/saved_model/svc_rbf_14...
# Copying gs://human_proteins/saved_model/svc_rbf_15...
# Copying gs://human_proteins/saved_model/svc_rbf_16...
# Copying gs://human_proteins/saved_model/svc_rbf_17...
# Copying gs://human_proteins/saved_model/svc_rbf_18...
# Copying gs://human_proteins/saved_model/svc_rbf_19...
# Copying gs://human_proteins/saved_model/svc_rbf_2...
# Copying gs://human_proteins/saved_model/svc_rbf_20...
# Copying gs://human_proteins/saved_model/svc_rbf_21...
# Copying gs://human_proteins/saved_model/svc_rbf_22...
# Copying gs://human_proteins/saved_model/svc_rbf_23...
# Copying gs://human_proteins/saved_model/svc_rbf_24...
# Copying gs://human_proteins/saved_model/svc_rbf_25...
# Copying gs://human_proteins/saved_model/svc_rbf_26...
# Copying gs://human_proteins/saved_model/svc_rbf_27...
# Copying gs://human_proteins/saved_model/svc_rbf_3...
# Copying gs://human_proteins/saved_model/svc_rbf_4...
# Copying gs://human_proteins/saved_model/svc_rbf_5...
# Copying gs://human_proteins/saved_model/svc_rbf_6...
# Copying gs://human_proteins/saved_model/svc_rbf_7...
# Copying gs://human_proteins/saved_model/svc_rbf_8...
# Copying gs://human_proteins/saved_model/svc_rbf_9...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_0...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_1...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_10...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_11...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_12...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_13...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_14...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_15...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_16...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_17...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_18...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_19...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_2...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_20...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_21...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_22...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_23...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_24...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_25...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_26...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_27...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_3...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_4...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_5...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_6...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_7...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_8...
# Copying gs://human_proteins/saved_model/svc_rbf_C0_1_9...
# Copying gs://human_proteins/saved_model/xgboostclass_0...
# Copying gs://human_proteins/saved_model/xgboostclass_1...
# Copying gs://human_proteins/saved_model/xgboostclass_10...
# Copying gs://human_proteins/saved_model/xgboostclass_11...
# Copying gs://human_proteins/saved_model/xgboostclass_12...
# Copying gs://human_proteins/saved_model/xgboostclass_13...
# Copying gs://human_proteins/saved_model/xgboostclass_14...
# Copying gs://human_proteins/saved_model/xgboostclass_15...
# Copying gs://human_proteins/saved_model/xgboostclass_16...
# Copying gs://human_proteins/saved_model/xgboostclass_17...
# Copying gs://human_proteins/saved_model/xgboostclass_18...
# Copying gs://human_proteins/saved_model/xgboostclass_19...
# Copying gs://human_proteins/saved_model/xgboostclass_2...
# Copying gs://human_proteins/saved_model/xgboostclass_20...
# Copying gs://human_proteins/saved_model/xgboostclass_21...
# Copying gs://human_proteins/saved_model/xgboostclass_22...
# Copying gs://human_proteins/saved_model/xgboostclass_23...
# Copying gs://human_proteins/saved_model/xgboostclass_24...
# Copying gs://human_proteins/saved_model/xgboostclass_25...
# Copying gs://human_proteins/saved_model/xgboostclass_26...
# Copying gs://human_proteins/saved_model/xgboostclass_27...
# Copying gs://human_proteins/saved_model/xgboostclass_3...
# Copying gs://human_proteins/saved_model/xgboostclass_4...
# Copying gs://human_proteins/saved_model/xgboostclass_5...
# Copying gs://human_proteins/saved_model/xgboostclass_6...
# Copying gs://human_proteins/saved_model/xgboostclass_7...
# Copying gs://human_proteins/saved_model/xgboostclass_8...
# Copying gs://human_proteins/saved_model/xgboostclass_9...
# \ [448 files][  6.5 GiB/  6.5 GiB]   11.6 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 448 objects/6.5 GiB.

# %%
df_score = pd.DataFrame(index=range(28))
for filename in os.listdir('/tmp/saved_model/saved_model'):
    f_path = os.path.join('/tmp/saved_model/saved_model', filename)
    try:
      if filename[0:2] != 'nn':
        my_model,y_pred, y_test, pipe = joblib.load(f_path)
      elif not 'model' in filename:
        y_pred, y_test = joblib.load(f_path)  
      else:
        continue
      model, loc_number = filename.rsplit('_', 1)
      if not model in df_score.columns:
        list_model = np.zeros(28)
        df_score[model] = list_model
      try:
        df_score.loc[df_score.index[int(loc_number)],model]= f1_score(y_test, y_pred).round(2)
      except ValueError:
        continue
    except IsADirectoryError:
      continue

# %%
df_score
# Out:
#      KNN  GradientBoostingClassifier  ExtraT_Bea  PAC_Bea  RiCcv_Bea  \
# 0   0.64                        0.64        0.78     0.63       0.72
# 1   0.62                        0.62        0.72     0.60       0.66
# 2   0.63                        0.63        0.83     0.59       0.67
# 3   0.62                        0.62        0.66     0.54       0.63
# 4   0.62                        0.62        0.67     0.59       0.63
# 5   0.60                        0.60        0.70     0.56       0.63
# 6   0.63                        0.63        0.65     0.59       0.63
# 7   0.61                        0.61        0.62     0.58       0.59
# 8   0.71                        0.71        0.65     0.64       0.59
# 9   0.64                        0.64        0.65     0.59       0.58
# 10  0.53                        0.53        0.60     0.50       0.67
# 11  0.67                        0.67        0.69     0.63       0.61
# 12  0.74                        0.74        0.81     0.74       0.65
# 13  0.74                        0.74        0.71     0.64       0.52
# 14  0.76                        0.76        0.78     0.85       0.76
# 15  0.44                        0.44        0.29     0.22       0.40
# 16  0.70                        0.70        0.65     0.66       0.56
# 17  0.79                        0.79        0.85     0.70       0.72
# 18  0.68                        0.68        0.63     0.62       0.56
# 19  0.62                        0.62        0.65     0.60       0.59
# 20  0.63                        0.63        0.67     0.66       0.67
# 21  0.66                        0.66        0.73     0.68       0.71
# 22  0.73                        0.73        0.70     0.67       0.61
# 23  0.62                        0.62        0.63     0.61       0.63
# 24  0.87                        0.87        0.90     0.86       0.79
# 25  0.64                        0.64        0.72     0.65       0.68
# 26  0.60                        0.60        0.61     0.63       0.58
# 27  0.57                        0.57        0.67     0.86       0.75
#
#     nn_5_layers_dropout  xgboostclass  BerNB_Bea  svc_rbf_C0_1  svc_rbf  \
# 0                   0.0          0.70       0.58          0.70     0.76
# 1                   0.0          0.64       0.58          0.60     0.68
# 2                   0.0          0.65       0.60          0.63     0.72
# 3                   0.0          0.62       0.57          0.62     0.66
# 4                   0.0          0.62       0.59          0.64     0.68
# 5                   0.0          0.63       0.58          0.62     0.67
# 6                   0.0          0.65       0.57          0.56     0.69
# 7                   0.0          0.62       0.53          0.49     0.63
# 8                   0.0          0.61       0.53          0.49     0.69
# 9                   0.0          0.62       0.57          0.63     0.65
# 10                  0.0          0.73       0.62          0.53     0.73
# 11                  0.0          0.65       0.58          0.64     0.68
# 12                  0.0          0.80       0.76          0.78     0.79
# 13                  0.0          0.70       0.62          0.66     0.73
# 14                  0.0          0.81       0.73          0.76     0.84
# 15                  0.0          0.50       0.50          0.00     0.25
# 16                  0.0          0.66       0.59          0.65     0.68
# 17                  0.0          0.79       0.72          0.74     0.78
# 18                  0.0          0.65       0.51          0.44     0.70
# 19                  0.0          0.63       0.54          0.58     0.66
# 20                  0.0          0.66       0.70          0.64     0.65
# 21                  0.0          0.72       0.66          0.70     0.75
# 22                  0.0          0.74       0.68          0.67     0.72
# 23                  0.0          0.61       0.54          0.52     0.65
# 24                  0.0          0.84       0.72          0.84     0.91
# 25                  0.0          0.68       0.60          0.68     0.72
# 26                  0.0          0.61       0.58          0.56     0.64
# 27                  0.0          0.89       0.57          0.00     0.86
#
#     Ada_Bea  RF_Bea
# 0      0.66    0.76
# 1      0.62    0.70
# 2      0.62    0.80
# 3      0.60    0.63
# 4      0.60    0.66
# 5      0.61    0.68
# 6      0.63    0.65
# 7      0.56    0.61
# 8      0.60    0.66
# 9      0.60    0.66
# 10     0.80    0.67
# 11     0.60    0.66
# 12     0.74    0.79
# 13     0.64    0.67
# 14     0.79    0.78
# 15     0.60    0.67
# 16     0.59    0.67
# 17     0.79    0.79
# 18     0.62    0.63
# 19     0.59    0.64
# 20     0.59    0.71
# 21     0.70    0.73
# 22     0.66    0.69
# 23     0.60    0.63
# 24     0.84    0.89
# 25     0.64    0.71
# 26     0.59    0.62
# 27     0.75    0.86

# %%
df_score.loc[len(df_score.index)] = [sum(df_score[model][0:28])/28 for model in df_score.columns]

# %%
from pathlib import Path  
filepath = Path('tmp/f1_scores.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_score.to_csv(filepath)

# %%
# !gsutil cp -r 'tmp/f1_scores.csv' gs://human_proteins/
# Out:
# Copying file://tmp/f1_scores.csv [Content-Type=text/csv]...
# -
# Operation completed over 1 objects/2.0 KiB.
