# %% [markdown]
# ## Finding the best fitting regression model for binary subset of the data (one protein at a time)
# - for a given protein, fit a regression model and optimize for the best fit
# - using embeddings (efficientnet.tfkeras import EfficientNetB0) as input features

# %%
# Import all the libraries I need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ignore Deprecation Warning
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import plot_confusion_matrix, recall_score, accuracy_score, precision_score
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, QuantileTransformer
from sklearn.pipeline import make_pipeline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

import xgboost as xgb

import pyarrow.parquet as pq

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Set base path

base_path = '/Users/reneebrecht/neue_fische/human-protein-atlas-image-classification/data/'
embed_path = '/Users/reneebrecht/neue_fische/human-protein-atlas-image-classification/data/embeddings_train/'

# %% [markdown]
# ### Loading the image labels and image names

# %%
#get all of the labels
labels_training = pd.read_csv(base_path+'train.csv')

# %% [markdown]
# ### Some setup

# %%
class Location_in_Target(object):
    ''' Class to get a list of name of pictures which are labeled with a specific 
        location and the same number of names of pictures which labels do not 
        contain the specific location.
        ...
        Attributes:
        ----------
        location: int 
            number which define a location in a human cell
        pictures: panda.DataFrame
            list of the names of the pictures labeled with the location and 
            same number of pictures without the label
        
        Methods:
        ----------
        save_pictures(pictures, column_name):
            Saves the list of picture names in an Attribute
        get_pictures()
            Returns the list of picture names
        determine_pictures(labels)  
            Find pictures with and without the specific label and call save method
            when list is build
    '''

    def __init__(self, location): 
        '''Parameters
           ----------
           location: int 
                number which define a location in a human cell
        '''

        self.location = location
        self.pictures = pd.DataFrame()

    def save_pictures(self, pictures, column_name):
        ''' Saves the list of pictures in the attribute pictures

            Parameters
            ----------
            pictures: panda.DataFrame
                list of the names of the pictures labeled with the location and 
                same number of pictures without the label
            column_name: str
                Description of the data saved in the DataFrame used as column names 
        '''

        self.pictures[column_name] = pictures

    def get_pictures(self):
        '''Gives back the list of picture names which are labeled or not labeled
            with the given location
        '''

        return self.pictures

    def determine_pictures(self, labels):
        ''' First the names of the pictures labeled with the given location are 
            saved in a list and the method to save it in a DataFrame column is 
            called. 
            The same number of names from pictures not labeled with the location 
            are chosen randomly. The saving function is called with it again. 

            Parameters
            ----------
            labels: DataFrame with all picture names and Targets       
        '''

        pictures = [label.Id  for index, label in labels.iterrows() 
                              if str(self.location) in label.Target]
        self.save_pictures(pictures, f'pictures_with_location_{self.location}')
        #The number of pictures labeled with the given location is needed to get the 
        #same number of pictures not labeled with the location
        number_needed_pictures= len(pictures)
        pictures = [label.Id  for index, label in labels.iterrows() 
                              if str(self.location) not in label.Target]
        self.save_pictures(np.random.choice(pictures, number_needed_pictures),
                                f'pictures_without_location_{self.location}')

# courtesy of https://www.kaggle.com/code/allunia/protein-atlas-exploration-and-baseline
label_names = {
    0:  "Nucleoplasm",  
    1:  "Nuclear membrane",   
    2:  "Nucleoli",   
    3:  "Nucleoli fibrillar center",   
    4:  "Nuclear speckles",
    5:  "Nuclear bodies",   
    6:  "Endoplasmic reticulum",   
    7:  "Golgi apparatus",   
    8:  "Peroxisomes",   
    9:  "Endosomes",   
    10:  "Lysosomes",   
    11:  "Intermediate filaments",   
    12:  "Actin filaments",   
    13:  "Focal adhesion sites",   
    14:  "Microtubules",   
    15:  "Microtubule ends",   
    16:  "Cytokinetic bridge",   
    17:  "Mitotic spindle",   
    18:  "Microtubule organizing center",   
    19:  "Centrosome",   
    20:  "Lipid droplets",   
    21:  "Plasma membrane",   
    22:  "Cell junctions",   
    23:  "Mitochondria",   
    24:  "Aggresome",   
    25:  "Cytosol",   
    26:  "Cytoplasmic bodies",   
    27:  "Rods & rings"
}

reverse_train_labels = dict((v,k) for k,v in label_names.items())

# %% [markdown]
# #### Load the full set of embeddings

# %%
# load embeddings (saved as parquet files), convert to pandas and get strings as strings
emb = pq.read_table(embed_path).to_pandas()
for col in ['target_id', 'image_path', 'image_name']:
    emb[col] = emb[col].str.decode('utf-8')#.fillna(df[col]) 
emb
# Out:
#       target_id                                         image_path  \
# 0             7  ../data/train/4b0d7acc-bbb5-11e8-b2ba-ac1f6b64...
# 1           5 0  ../data/train/4b0e4648-bbc2-11e8-b2bb-ac1f6b64...
# 2            23  ../data/train/4b0fe352-bbbf-11e8-b2ba-ac1f6b64...
# 3             2  ../data/train/4b1164e4-bbaf-11e8-b2ba-ac1f6b64...
# 4            25  ../data/train/4b120c9e-bbb1-11e8-b2ba-ac1f6b64...
# ...         ...                                                ...
# 31067         7  ../data/train/9d04d730-bbb5-11e8-b2ba-ac1f6b64...
# 31068         4  ../data/train/9d09c7e0-bb9c-11e8-b2b9-ac1f6b64...
# 31069         0  ../data/train/9d0a7012-bbc6-11e8-b2bc-ac1f6b64...
# 31070      25 0  ../data/train/9d10ecec-bba0-11e8-b2b9-ac1f6b64...
# 31071       7 0  ../data/train/9d114136-bbb6-11e8-b2ba-ac1f6b64...
#
#                                                embedding  \
# 0      [-0.14782768, -0.19346946, 0.029495712, -0.114...
# 1      [-0.11768038, 0.108380914, -0.07158355, -0.051...
# 2      [-0.14264518, -0.14894637, 0.015262008, -0.138...
# 3      [-0.14977421, -0.12706101, -0.17702478, -0.087...
# 4      [-0.15020615, -0.008659467, -0.14262204, -0.04...
# ...                                                  ...
# 31067  [-0.095827445, -0.14014255, -0.1306586, -0.081...
# 31068  [-0.109680824, -0.07402489, -0.08704822, -0.08...
# 31069  [-0.14760047, -0.105946906, 0.17695697, -0.130...
# 31070  [-0.12235144, -0.12698074, -0.052961998, -0.10...
# 31071  [-0.1314421, -0.13573745, -0.14491996, -0.0963...
#
#                                  image_name
# 0      4b0d7acc-bbb5-11e8-b2ba-ac1f6b6435d0
# 1      4b0e4648-bbc2-11e8-b2bb-ac1f6b6435d0
# 2      4b0fe352-bbbf-11e8-b2ba-ac1f6b6435d0
# 3      4b1164e4-bbaf-11e8-b2ba-ac1f6b6435d0
# 4      4b120c9e-bbb1-11e8-b2ba-ac1f6b6435d0
# ...                                     ...
# 31067  9d04d730-bbb5-11e8-b2ba-ac1f6b6435d0
# 31068  9d09c7e0-bb9c-11e8-b2b9-ac1f6b6435d0
# 31069  9d0a7012-bbc6-11e8-b2bc-ac1f6b6435d0
# 31070  9d10ecec-bba0-11e8-b2b9-ac1f6b6435d0
# 31071  9d114136-bbb6-11e8-b2ba-ac1f6b6435d0
#
# [31072 rows x 4 columns]

# %% [markdown]
# #### Test the class with Mitochondria labeled with a 23
# - create a balanced subset of images that have mitochondria or not

# %%
# INPUT: select the protein of interest and it's number
protein_name = 'Cytosol'
protein_number = 25

# %%
# picking out all the images/embeddings with the protein
selected_protein = Location_in_Target(location = protein_number)
selected_protein.determine_pictures(labels_training)
#Dataframe with filenames of pictures which have mitochondria
df_pro = selected_protein.get_pictures().pictures_with_location_25
#Dataframe with filenames of pictures which have no mitochondria
df_no_pro = selected_protein.get_pictures().pictures_without_location_25

# %%
# use join to pull out the embeddings of the mitochondria subset
# first get the mitochondria and set target = 1
emb_pro = emb.merge(df_pro.rename("image_name").to_frame(), how="right", on="image_name")
emb_pro["target_id"] = 1
# now the others, target = 0
emb_no_pro = emb.merge(df_no_pro.rename("image_name").to_frame(), how="right", on="image_name")
emb_no_pro["target_id"] = 0
# now combine them into one table and shuffle
df_emb_pro = pd.concat([emb_pro, emb_no_pro]).reset_index()
df_emb_pro = shuffle(df_emb_pro, random_state=0)

# %%
# put the features (embeddings) in one dataframe
df_feats = pd.DataFrame(list(map(np.ravel, df_emb_pro.embedding)))

# %%
# get the targets, one hot encode and put into a dataframe
# target dataframe
targets = df_emb_pro['target_id']
targets
# Out:
# 16320    0
# 10455    0
# 3197     1
# 12602    0
# 1476     1
#         ..
# 9225     0
# 13123    0
# 9845     0
# 10799    0
# 2732     1
# Name: target_id, Length: 16456, dtype: int64

# %%
sns.pairplot(pd.concat([df_feats,targets],axis=1).iloc[:,-10:], hue="target_id");

# %% [markdown]
# #### Notes:
# - data may still need to be scaled
# - also not uniformly distributed --- log?

# %%
# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(df_feats, targets, random_state=1)

# %% [markdown]
# ### Setup pipeline to preprocess data and train the model
# - setting up "switcher class" so that we can try different models/classifiers; from https://stackoverflow.com/questions/51695322/compare-multiple-algorithms-with-sklearn-pipeline

# %% [markdown]
# !!! reduce overfitting
# - try with, without quantile and scaler
# - add regularization
# - ...

# %%
from sklearn.base import BaseEstimator

class ClfSwitcher(BaseEstimator):
    def __init__(
        self, 
        estimator = KNeighborsClassifier(),
    ):
        """
        A Custom BaseEstimator that can switch between classifiers.
        :param estimator: sklearn object - The classifier
        """ 

        self.estimator = estimator


    def fit(self, X, y=None, **kwargs):
        self.estimator.fit(X, y)
        return self


    def predict(self, X, y=None):
        return self.estimator.predict(X)


    def predict_proba(self, X):
        return self.estimator.predict_proba(X)


    def score(self, X, y):
        return self.estimator.score(X, y)

# %% [markdown]
# #### Compare different models (and some hyperparameters)

# %%
# Define fbeta score as the metric to compare the models
f_beta = 1
fbeta_scorer = make_scorer(fbeta_score, beta=f_beta)

# %%
pipeline = Pipeline([
    ('quant', QuantileTransformer(random_state=0)), 
    ('stscale',StandardScaler()),
    ('clf', ClfSwitcher()),
])

# set up the different models like hyperparameters
# list_of_clf = [LogisticRegression(), KNeighborsClassifier(), SVC(), DecisionTreeClassifier(random_state=42)]

parameters = [
#    {
#        'clf__estimator': [SGDClassifier()], 
#        'clf__estimator__penalty': ('l2'), # , 'elasticnet', 'l1'
#    },    
    #{
    #    'clf__estimator': [DecisionTreeClassifier(random_state=42)], 
    #},    
    {
        # 'clf__estimator': [KNeighborsClassifier()], #n_neighbors=3, p=1
        # 'clf__estimator__p': [1],
        # 'clf__estimator__n_neighbors': [3],
    },
#    {
#        'clf__estimator': [LogisticRegression()], 
#        'clf__estimator__penalty': ('l2'),
#    },
    # {
    #     'clf__estimator': [LinearSVC()], 
    #     'clf__estimator__penalty': ['l2'],
    #     'clf__estimator__loss': ['hinge'], #,'squared_hinge'], # , 
    #     'clf__estimator__C': [1e-3], #, 1e-2], # 1e-4, 1
    # #    'clf__estimator__dual': ['False']
    # },
    {
        'clf__estimator': [SVC()], 
        'clf__estimator__kernel': ['rbf'], #, 'sigmoid'], #'linear', ,'poly'
        'clf__estimator__C': [0.01, 0.1, 0.5], #, 1], # 0.1, 1, 
        'clf__estimator__gamma': [0.01, 0.1, 0.5, 1, 2, 5] #, 'auto', 'scale']
    },
    # { just gives nan, can't handle negative data
    #     'clf__estimator': [MultinomialNB()], 
    # },
]

gscv = GridSearchCV(pipeline, parameters, cv=5, n_jobs=12, return_train_score=True, verbose=3,
                    scoring=fbeta_scorer)
gscv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 19 candidates, totalling 95 fits
# [CV 1/5] END ..............., score=(train=0.768, test=0.635) total time=  17.5s
# [CV 4/5] END ..............., score=(train=0.761, test=0.641) total time=  17.5s
# [CV 2/5] END ..............., score=(train=0.771, test=0.640) total time=  18.4s
# [CV 3/5] END ..............., score=(train=0.773, test=0.633) total time=  18.3s
# [CV 5/5] END ..............., score=(train=0.764, test=0.626) total time=  18.0s
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.8min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.0min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.0min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.0min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.0min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.1min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 8.1min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.6min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.6min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.7min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.7min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 7.9min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 7.3min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.3min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 7.3min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.3min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.4min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.4min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.3min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 7.3min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.1min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.2min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.2min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.3min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 8.3min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.01, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.2min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.3min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.002, test=0.002) total time= 8.2min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 8.4min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.1min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.3min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 8.2min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.6min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.5min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.6min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.5min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.6min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.5min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.5min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.5min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.5min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time=10.2min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time=10.1min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time=10.0min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.1min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.4min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.4min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.4min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.4min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 9.8min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.000, test=0.000) total time= 7.2min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.1, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.671, test=0.648) total time= 9.8min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.995, test=0.218) total time= 8.2min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.992, test=0.711) total time= 8.2min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.994, test=0.177) total time= 8.2min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.979, test=0.690) total time= 8.3min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.999, test=0.711) total time= 8.1min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.01, clf__estimator__kernel=rbf;, score=(train=0.994, test=0.444) total time= 8.2min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.999, test=0.713) total time= 8.1min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.999, test=0.013) total time= 7.2min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.999, test=0.718) total time= 7.1min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.710) total time= 6.9min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.1, clf__estimator__kernel=rbf;, score=(train=0.720, test=0.652) total time=10.6min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.713) total time= 6.6min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.005) total time= 6.9min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.710) total time= 6.8min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.719) total time= 6.8min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.713) total time= 6.9min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.002) total time= 6.9min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.719) total time= 6.6min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.710) total time= 6.6min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=0.5, clf__estimator__kernel=rbf;, score=(train=0.719, test=0.652) total time= 9.9min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.712) total time= 6.5min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=1, clf__estimator__kernel=rbf;, score=(train=0.719, test=0.652) total time= 9.9min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.002) total time= 6.1min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=0.719, test=0.652) total time= 9.6min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=2, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.720) total time= 5.8min
# [CV 1/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.710) total time= 5.7min
# [CV 2/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.712) total time= 5.7min
# [CV 4/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.002) total time= 4.9min
# [CV 5/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=1.000, test=0.720) total time= 4.3min
# [CV 3/5] END clf__estimator=SVC(), clf__estimator__C=0.5, clf__estimator__gamma=5, clf__estimator__kernel=rbf;, score=(train=0.718, test=0.652) total time= 6.7min
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('quant',
#                                         QuantileTransformer(random_state=0)),
#                                        ('stscale', StandardScaler()),
#                                        ('clf', ClfSwitcher())]),
#              n_jobs=12,
#              param_grid=[{},
#                          {'clf__estimator': [SVC()],
#                           'clf__estimator__C': [0.01, 0.1, 0.5],
#                           'clf__estimator__gamma': [0.01, 0.1, 0.5, 1, 2, 5],
#                           'clf__estimator__kernel': ['rbf']}],
#              return_train_score=True, scoring=make_scorer(fbeta_score, beta=1),
#              verbose=3)

# %% [markdown]
# #### Notes:
# - check the output of the QuantileTransformer, does it make distributions uniform?
# - need to deal with overfitting
# -

# %%
df_grid = pd.DataFrame(gscv.cv_results_)
df_grid.plot(y=['mean_test_score', 'mean_train_score'])
df_grid
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        8.388136      0.560725         9.548998        0.278375
# 1      390.434930      6.632348        89.347300        1.633944
# 2      382.630189      6.039356        88.067705        2.085867
# 3      355.445366     11.166861        88.849975        2.436572
# 4      342.612778      4.658618        94.672203        8.690194
# 5      335.132616     20.161536       113.477443        2.677051
# 6      379.665148      5.338801       113.805898        3.725449
# 7      392.206774      4.549785       105.115884        2.669414
# 8      392.441629     60.368277       101.605751        0.972004
# 9      382.312014     60.537104        99.307661        1.293464
# 10     370.955979     69.151863       100.290875        6.108728
# 11     359.530484     67.921033       107.330429        8.478224
# 12     363.151383     65.312020       104.071618       10.338637
# 13     388.761683      1.648321       104.506081        0.699036
# 14     395.753354     76.013292        97.732723        5.397272
# 15     353.181359     77.360273        91.562952        3.139914
# 16     357.520445     77.208755        88.002249        3.990601
# 17     331.266049     66.803643        84.137517       16.747564
# 18     274.613909     51.116591        53.678010        5.127050
#
#    param_clf__estimator param_clf__estimator__C param_clf__estimator__gamma  \
# 0                   NaN                     NaN                         NaN
# 1                 SVC()                    0.01                        0.01
# 2                 SVC()                    0.01                         0.1
# 3                 SVC()                    0.01                         0.5
# 4                 SVC()                    0.01                           1
# 5                 SVC()                    0.01                           2
# 6                 SVC()                    0.01                           5
# 7                 SVC()                     0.1                        0.01
# 8                 SVC()                     0.1                         0.1
# 9                 SVC()                     0.1                         0.5
# 10                SVC()                     0.1                           1
# 11                SVC()                     0.1                           2
# 12                SVC()                     0.1                           5
# 13                SVC()                     0.5                        0.01
# 14                SVC()                     0.5                         0.1
# 15                SVC()                     0.5                         0.5
# 16                SVC()                     0.5                           1
# 17                SVC()                     0.5                           2
# 18                SVC()                     0.5                           5
#
#    param_clf__estimator__kernel  \
# 0                           NaN
# 1                           rbf
# 2                           rbf
# 3                           rbf
# 4                           rbf
# 5                           rbf
# 6                           rbf
# 7                           rbf
# 8                           rbf
# 9                           rbf
# 10                          rbf
# 11                          rbf
# 12                          rbf
# 13                          rbf
# 14                          rbf
# 15                          rbf
# 16                          rbf
# 17                          rbf
# 18                          rbf
#
#                                                params  split0_test_score  ...  \
# 0                                                  {}           0.634765  ...
# 1   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 2   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 3   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 4   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 5   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 6   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 7   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 8   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 9   {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 10  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 11  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 12  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.000000  ...
# 13  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.217835  ...
# 14  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.710564  ...
# 15  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.710083  ...
# 16  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.710083  ...
# 17  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.710451  ...
# 18  {'clf__estimator': SVC(), 'clf__estimator__C':...           0.710248  ...
#
#     mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0          0.634913        0.005122                1            0.768044
# 1          0.129682        0.259365                9            0.000000
# 2          0.129682        0.259365                9            0.000000
# 3          0.129682        0.259365                9            0.000000
# 4          0.129682        0.259365                9            0.000000
# 5          0.129682        0.259365                9            0.000000
# 6          0.129682        0.259365                9            0.000000
# 7          0.130007        0.259203                8            0.000000
# 8          0.129682        0.259365                9            0.000000
# 9          0.129682        0.259365                9            0.000000
# 10         0.129682        0.259365                9            0.000000
# 11         0.129682        0.259365                9            0.000000
# 12         0.129682        0.259365                9            0.000000
# 13         0.447931        0.225310                7            0.994632
# 14         0.561189        0.275381                2            0.999390
# 15         0.559675        0.278535                3            0.999797
# 16         0.559047        0.279788                6            0.999898
# 17         0.559146        0.279843                4            0.999898
# 18         0.559064        0.279799                5            1.000000
#
#     split1_train_score  split2_train_score  split3_train_score  \
# 0             0.770579            0.773111            0.760749
# 1             0.000000            0.670616            0.000000
# 2             0.000000            0.670616            0.000000
# 3             0.000000            0.670616            0.000000
# 4             0.000000            0.670616            0.000000
# 5             0.000000            0.670616            0.000000
# 6             0.000000            0.670616            0.000000
# 7             0.001620            0.670616            0.000000
# 8             0.000000            0.670616            0.000000
# 9             0.000000            0.670616            0.000000
# 10            0.000000            0.670616            0.000000
# 11            0.000000            0.670616            0.000000
# 12            0.000000            0.670616            0.000000
# 13            0.991536            0.979222            0.994083
# 14            0.999089            0.719896            0.999183
# 15            0.999696            0.718615            0.999592
# 16            0.999899            0.718511            0.999898
# 17            1.000000            0.718552            0.999898
# 18            1.000000            0.718396            1.000000
#
#     split4_train_score  mean_train_score  std_train_score
# 0             0.763976          0.767292         0.004451
# 1             0.000000          0.134123         0.268246
# 2             0.000000          0.134123         0.268246
# 3             0.000000          0.134123         0.268246
# 4             0.000000          0.134123         0.268246
# 5             0.000000          0.134123         0.268246
# 6             0.000000          0.134123         0.268246
# 7             0.000000          0.134447         0.268085
# 8             0.000000          0.134123         0.268246
# 9             0.000000          0.134123         0.268246
# 10            0.000000          0.134123         0.268246
# 11            0.000000          0.134123         0.268246
# 12            0.000000          0.134123         0.268246
# 13            0.993722          0.990639         0.005804
# 14            0.999087          0.943329         0.111717
# 15            0.999695          0.943479         0.112432
# 16            0.999898          0.943621         0.112555
# 17            0.999898          0.943649         0.112549
# 18            1.000000          0.943679         0.112642
#
# [19 rows x 24 columns]

# %% [markdown]
# #### Notes:
# - comparing SVC and and linearSVC with regularization
#     - SVC regularization with gamma and C now working, and results are better than linearSVC
#     - best fits (ie not overfitting, train vs test score <3% difference) are with C=0.1, 0.5 and gamma = 0.5, 1, 2
#     - GridsearchCV gives best result ast C=1 and gamma = 0.5 but this is overfitting by a wide margin (ie it's the best test score, but test score is 30% less than train score)
# - tried a few more options with SVC and found best scores for:
#     - C = 0.01, 0.1, gamma = 0.01, 0.05, 0.1, 1, 2, 5
#
#
# <!-- Old notes:
# - best result was 0.6832 with: {'clf__estimator': SVC(C=10), 'clf__estimator__C': 10, 'clf__estimator__kernel': 'rbf'}
#     - but this is overfitting a lot (0.99 with training and < 0.68 for test)
#     - and regularization isn't an option
# - in order to use regularization need to use LinearSVC, which does not overfit as much, but slightly lower score 0.652
#     - {'clf__estimator': LinearSVC(C=0.01, loss='hinge'), 'clf__estimator__C': 0.01, 'clf__estimator__loss': 'hinge', 'clf__estimator__penalty': 'l2'} -->

# %% [markdown]
# ### Set up model chosen as best

# %%
pipeline = Pipeline([
    ('quant', QuantileTransformer(random_state=0)), 
    ('stscale',StandardScaler()),
    ('svc', SVC(kernel='rbf', C=0.1)),
])

selected_model = pipeline.fit(X_train, y_train)

# %% [markdown]
# ##### !!! Note:
# - with C=0.1, gamma=1, model never predicts 0, always guesses 1 when run on training and test below.
# - Not setting gamma works, and is better than using all defaults, ie not setting C; (doesn't overfit as much).
#
# ### !! how can this be? how to avoid this?

# %% [markdown]
# ### Run the best model on the training data

# %%
# Plot confusion matrix and classification report for best model
y_in = y_train
x_in = X_train
y_pred = selected_model.predict(x_in)

print("Best model on train data")
print("==="*20)
print("fbeta score:", fbeta_score(y_in, y_pred, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_in, y_pred))
print("---"*20)

cm = confusion_matrix(y_in, y_pred)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# Best model on train data
# ============================================================
# fbeta score: 0.7058
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.71      0.68      0.70      6177
#            1       0.69      0.72      0.71      6165
#
#     accuracy                           0.70     12342
#    macro avg       0.70      0.70      0.70     12342
# weighted avg       0.70      0.70      0.70     12342
#
# ------------------------------------------------------------

# %% [markdown]
# ### Predict with test data

# %%
# Plot confusion matrix and classification report for best model
y_in = y_test
x_in = X_test
y_pred = selected_model.predict(x_in)

print("Best model on train data")
print("==="*20)
print("fbeta score:", fbeta_score(y_in, y_pred, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_in, y_pred))
print("---"*20)

cm = confusion_matrix(y_in, y_pred)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# Best model on train data
# ============================================================
# fbeta score: 0.6711
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.64      0.65      2051
#            1       0.66      0.69      0.67      2063
#
#     accuracy                           0.66      4114
#    macro avg       0.66      0.66      0.66      4114
# weighted avg       0.66      0.66      0.66      4114
#
# ------------------------------------------------------------

# %% [markdown]
# ### Initial pipeline setup for a KNN model, using defaults

# %%
knn_pipe = make_pipeline(QuantileTransformer(random_state=0), StandardScaler(), 
                     KNeighborsClassifier(n_neighbors=5, metric='euclidean'))
knn_pipe.fit(X_train, y_train)  # apply scaling on training data
# Out:
# Pipeline(steps=[('quantiletransformer', QuantileTransformer(random_state=0)),
#                 ('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='euclidean'))])

# %% [markdown]
# ### Predict with train data

# %%
# Predict on test set
y_train_pred_knn = knn_pipe.predict(X_train)
f_beta = 1
print("KNN on train data")
print("==="*20)
print("fbeta score:", fbeta_score(y_train, y_train_pred_knn, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_train, y_train_pred_knn))
print("---"*20)


cm = confusion_matrix(y_train, y_train_pred_knn)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# KNN on train data
# ============================================================
# fbeta score: 0.7686
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77      6177
#            1       0.78      0.76      0.77      6165
#
#     accuracy                           0.77     12342
#    macro avg       0.77      0.77      0.77     12342
# weighted avg       0.77      0.77      0.77     12342
#
# ------------------------------------------------------------

# %% [markdown]
# ### Predict with test data

# %%
# Predict on test set
y_test_pred_knn = knn_pipe.predict(X_test)

print("KNN on test data")
print("==="*20)
print("fbeta score:", fbeta_score(y_test, y_test_pred_knn, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_test, y_test_pred_knn))
print("---"*20)


cm = confusion_matrix(y_test, y_test_pred_knn)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# KNN on test data
# ============================================================
# fbeta score: 0.6507
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.63      0.64      2051
#            1       0.64      0.66      0.65      2063
#
#     accuracy                           0.65      4114
#    macro avg       0.65      0.65      0.65      4114
# weighted avg       0.65      0.65      0.65      4114
#
# ------------------------------------------------------------

# %% [markdown]
# ### Initial pipeline setup for a GradientBoostingClassifier model, using defaults

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
xgb_pipe = Pipeline([
    ('quant', QuantileTransformer(random_state=0)), 
    ('stscale',StandardScaler()),
    ('xgb', GradientBoostingClassifier(n_estimators=1000, learning_rate=0.5,  max_depth=1, random_state=0))
    #('xgb', xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric=fbeta_scorer)),
])
# xgb_pipe = make_pipeline(QuantileTransformer(random_state=0), StandardScaler(), 
#                          xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric=fbeta_scorer)
#                         )
xgb_pipe.fit(X_train, y_train)  # apply scaling on training data
# Out:
# Pipeline(steps=[('quant', QuantileTransformer(random_state=0)),
#                 ('stscale', StandardScaler()),
#                 ('xgb',
#                  GradientBoostingClassifier(learning_rate=0.5, max_depth=1,
#                                             n_estimators=1000,
#                                             random_state=0))])

# %% [markdown]
# ### Predict with train data

# %%
# Predict on test set
y_train_pred_knn = xgb_pipe.predict(X_train)
f_beta = 1
print("XGBoost on train data")
print("==="*20)
print("fbeta score:", fbeta_score(y_train, y_train_pred_knn, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_train, y_train_pred_knn))
print("---"*20)


cm = confusion_matrix(y_train, y_train_pred_knn)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# XGBoost on train data
# ============================================================
# fbeta score: 0.8611
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86      6177
#            1       0.86      0.86      0.86      6165
#
#     accuracy                           0.86     12342
#    macro avg       0.86      0.86      0.86     12342
# weighted avg       0.86      0.86      0.86     12342
#
# ------------------------------------------------------------

# %% [markdown]
# ### Predict with test data

# %%
# Predict on test set
y_test_pred_knn = xgb_pipe.predict(X_test)

print("XGBoost on test data")
print("==="*20)
print("fbeta score:", fbeta_score(y_test, y_test_pred_knn, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_test, y_test_pred_knn))
print("---"*20)


cm = confusion_matrix(y_test, y_test_pred_knn)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# XGBoost on test data
# ============================================================
# fbeta score: 0.6897
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70      2051
#            1       0.70      0.68      0.69      2063
#
#     accuracy                           0.69      4114
#    macro avg       0.69      0.69      0.69      4114
# weighted avg       0.70      0.69      0.69      4114
#
# ------------------------------------------------------------

# %% [markdown]
# ### Initial pipeline setup for a XGBoost model, using defaults
# - xgboost overfits (all 1s)
# - need to run hyperparameter search

# %%
xgb_pipe = Pipeline([
    ('quant', QuantileTransformer(random_state=0)), 
    ('stscale',StandardScaler()),
    ('xgb', xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric=fbeta_scorer)),
])
# xgb_pipe = make_pipeline(QuantileTransformer(random_state=0), StandardScaler(), 
#                          xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric=fbeta_scorer)
#                         )
xgb_pipe.fit(X_train, y_train)  # apply scaling on training data
# Out:
# Pipeline(steps=[('quant', QuantileTransformer(random_state=0)),
#                 ('stscale', StandardScaler()),
#                 ('xgb',
#                  XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, early_stopping_rounds=None,
#                                enable_categorical=False,
#                                eval_metric=make_scorer(fbeta_score, beta=1),
#                                gamma=0, gpu_id=-1, grow_policy='depthwise',
#                                importance_type=None, interaction_constraints='',
#                                learning_rate=0.300000012, max_bin=256,
#                                max_cat_to_onehot=4, max_delta_step=0,
#                                max_depth=6, max_leaves=0, min_child_weight=1,
#                                missing=nan, monotone_constraints='()',
#                                n_estimators=100, n_jobs=0, num_parallel_tree=1,
#                                predictor='auto', random_state=42, reg_alpha=0,
#                                reg_lambda=1, ...))])

# %% [markdown]
# ### Predict with train data

# %%
# Predict on test set
y_train_pred_knn = xgb_pipe.predict(X_train)
f_beta = 1
print("XGBoost on train data")
print("==="*20)
print("fbeta score:", fbeta_score(y_train, y_train_pred_knn, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_train, y_train_pred_knn))
print("---"*20)


cm = confusion_matrix(y_train, y_train_pred_knn)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# XGBoost on train data
# ============================================================
# fbeta score: 0.9997
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6177
#            1       1.00      1.00      1.00      6165
#
#     accuracy                           1.00     12342
#    macro avg       1.00      1.00      1.00     12342
# weighted avg       1.00      1.00      1.00     12342
#
# ------------------------------------------------------------

# %% [markdown]
# ### Predict with test data

# %%
# Predict on test set
y_test_pred_knn = xgb_pipe.predict(X_test)

print("XGBoost on test data")
print("==="*20)
print("fbeta score:", fbeta_score(y_test, y_test_pred_knn, beta=f_beta).round(4))
print("---"*20)
print(classification_report(y_test, y_test_pred_knn))
print("---"*20)


cm = confusion_matrix(y_test, y_test_pred_knn)
sns.heatmap(cm, cmap="YlGnBu_r", annot=True, fmt=".0f");
# Out:
# XGBoost on test data
# ============================================================
# fbeta score: 0.6984
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70      2051
#            1       0.71      0.69      0.70      2063
#
#     accuracy                           0.70      4114
#    macro avg       0.70      0.70      0.70      4114
# weighted avg       0.70      0.70      0.70      4114
#
# ------------------------------------------------------------
